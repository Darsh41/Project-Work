# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Divya\Downloads\climate_nasa (1).csv")
df
# Out:
#                          date  likesCount  \
# 0    2022-09-07T17:12:32.000Z           2
# 1    2022-09-08T14:51:13.000Z           0
# 2    2022-09-07T17:19:41.000Z           1
# 3    2022-09-08T00:51:30.000Z           4
# 4    2022-09-07T19:06:20.000Z          16
# ..                        ...         ...
# 517  2022-12-22T17:21:37.000Z           0
# 518  2022-12-22T17:19:51.000Z           1
# 519  2022-12-22T17:12:57.000Z           3
# 520  2022-12-22T17:01:12.000Z           1
# 521  2022-12-22T17:00:08.000Z          12
#
#                                            profileName  commentsCount  \
# 0    4dca617d86b3fdce80ba7e81fb16e048c9cd9798cdfd6d...            NaN
# 1    518ab97f2d115ba5b6f03b2fba2ef2b120540c9681288b...            NaN
# 2    d82e8e24eb633fd625b0aef9b3cb625cfb044ceb8483e1...            3.0
# 3    37a509fa0b5177a2233c7e2d0e2b2d6916695fa9fba3f2...            NaN
# 4    e54fbbd42a729af9d04d9a5cc1f9bbfe8081a31c219ecb...           26.0
# ...

# %%
df.head()
# Out:
#                        date  likesCount  \
# 0  2022-09-07T17:12:32.000Z           2
# 1  2022-09-08T14:51:13.000Z           0
# 2  2022-09-07T17:19:41.000Z           1
# 3  2022-09-08T00:51:30.000Z           4
# 4  2022-09-07T19:06:20.000Z          16
#
#                                          profileName  commentsCount  \
# 0  4dca617d86b3fdce80ba7e81fb16e048c9cd9798cdfd6d...            NaN
# 1  518ab97f2d115ba5b6f03b2fba2ef2b120540c9681288b...            NaN
# 2  d82e8e24eb633fd625b0aef9b3cb625cfb044ceb8483e1...            3.0
# 3  37a509fa0b5177a2233c7e2d0e2b2d6916695fa9fba3f2...            NaN
# 4  e54fbbd42a729af9d04d9a5cc1f9bbfe8081a31c219ecb...           26.0
#
#                                                 text
# 0  Neat comparison I have not heard it before.\n ...
# 1  An excellent way to visualise the invisible! T...
# 2  Does the CO2/ghg in the troposphere affect the...
# 3  excellent post! I defo feel the difference - o...
# ...

# %%
df.tail()
# Out:
#                          date  likesCount  \
# 517  2022-12-22T17:21:37.000Z           0
# 518  2022-12-22T17:19:51.000Z           1
# 519  2022-12-22T17:12:57.000Z           3
# 520  2022-12-22T17:01:12.000Z           1
# 521  2022-12-22T17:00:08.000Z          12
#
#                                            profileName  commentsCount  \
# 517  9e17b1a6422032d47472f0216c73aafda7587e302eed5e...            NaN
# 518  48e55d898603a136aefc44771f248bffd67242583a462a...            5.0
# 519  ca5d2611814cf8c9844ed06d9916d876d2dba94dac5ff2...            NaN
# 520  a87c8aea74c9b97002b368d6143ce9c2809dcaec3103fb...            NaN
# 521  cc70f6c9dcc2637b1c5fd90046834612627c752b828cb4...            1.0
#
#                                                   text
# 517                     One can only hope for a peak 😞
# 518  what is the error margin for the temperature e...
# 519  We all should volenteerly help in reducing Glo...
# 520                                       Sergio Yepes
# ...

# %%
df.describe()
# Out:
#        likesCount  commentsCount
# count  522.000000     244.000000
# mean     4.720307       8.696721
# std     12.053556      12.266176
# min      0.000000       1.000000
# 25%      0.000000       2.000000
# 50%      1.000000       5.000000
# 75%      4.000000      10.000000
# max    126.000000      93.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           522 non-null    object
#  1   likesCount     522 non-null    int64
#  2   profileName    522 non-null    object
#  3   commentsCount  244 non-null    float64
#  4   text           504 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 20.5+ KB

# %%
df.shape
# Out:
# (522, 5)

# %%
df.dtypes
# Out:
# date              object
# likesCount         int64
# profileName       object
# commentsCount    float64
# text              object
# dtype: object

# %%
df.columns
# Out:
# Index(['date', 'likesCount', 'profileName', 'commentsCount', 'text'], dtype='object')

# %%
df.isnull().sum()
# Out:
# date               0
# likesCount         0
# profileName        0
# commentsCount    278
# text              18
# dtype: int64

# %%
df.dropna()
# Out:
#                          date  likesCount  \
# 2    2022-09-07T17:19:41.000Z           1
# 4    2022-09-07T19:06:20.000Z          16
# 5    2022-09-15T17:10:57.000Z           4
# 7    2022-09-07T18:07:53.000Z           1
# 9    2022-09-07T16:30:55.000Z           4
# ..                        ...         ...
# 508  2022-12-22T19:39:27.000Z           3
# 511  2022-12-22T17:55:09.000Z           3
# 514  2022-12-22T17:46:40.000Z           1
# 518  2022-12-22T17:19:51.000Z           1
# 521  2022-12-22T17:00:08.000Z          12
#
#                                            profileName  commentsCount  \
# 2    d82e8e24eb633fd625b0aef9b3cb625cfb044ceb8483e1...            3.0
# 4    e54fbbd42a729af9d04d9a5cc1f9bbfe8081a31c219ecb...           26.0
# 5    191055fb869d185092abf1405f0b2f4abe73bcaa9beb85...            1.0
# 7    39c3ec5a079b6b1a62577a1d13d4e8f894c5525575b85d...           21.0
# 9    31fd4cfea1a56eb21ad6a86ce4ed94e6a15e654b3557bf...            8.0
# ...

# %%
df.isnull().sum()
# Out:
# date               0
# likesCount         0
# profileName        0
# commentsCount    278
# text              18
# dtype: int64

# %%
df['commentsCount'].dropna
# Out:
# <bound method Series.dropna of 0       NaN
# 1       NaN
# 2       3.0
# 3       NaN
# 4      26.0
#        ...
# 517     NaN
# 518     5.0
# 519     NaN
# 520     NaN
# 521     1.0
# Name: commentsCount, Length: 522, dtype: float64>

# %%
df['commentsCount'].isna().sum()
# Out:
# 278

# %%
df['commentsCount'].fillna(0,inplace=True)

# %%
df['commentsCount'].isna().sum()
# Out:
# 0

# %%
df['text'].fillna('',inplace=True)
# Out:
# C:\Users\Divya\AppData\Local\Temp\ipykernel_10192\1456431344.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['text'].fillna('',inplace=True)

# %%
df['text'].isna().sum()
# Out:
# 0

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date'].dtypes
# Out:
# datetime64[ns, UTC]

# %%
daily_data = df.groupby('date')[['likesCount', 'commentsCount']].sum()
print(daily_data)
# Out:
#                            likesCount  commentsCount
# date
# 2020-09-15 21:25:05+00:00          27            6.0
# 2020-09-15 21:30:35+00:00           7            8.0
# 2020-09-15 21:32:15+00:00           4            0.0
# 2020-09-15 21:36:05+00:00           3            7.0
# 2020-09-15 21:36:59+00:00          16            8.0
# ...                               ...            ...
# 2023-12-17 16:43:53+00:00           3            0.0
# 2023-12-20 18:15:56+00:00           0            0.0
# 2023-12-22 15:27:58+00:00           0            0.0
# 2023-12-24 07:26:22+00:00           0            0.0
# 2023-12-25 13:34:39+00:00           0            0.0
#
# [522 rows x 2 columns]

# %%
plt.figure(figsize=(14, 7))
plt.plot(daily_data.index, daily_data['likesCount'], label='Likes Count', color='blue', marker='o')
plt.plot(daily_data.index, daily_data['commentsCount'], label='Comments Count', color='green', marker='x')

plt.title('Trends in Likes and Comments Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Metrics', fontsize=10)
plt.grid(alpha=0.5)
plt.tight_layout()

plt.show()

# %%
likes=df['likesCount'].describe()
commes=df['commentsCount'].describe()
likes
# Out:
# count    522.000000
# mean       4.720307
# std       12.053556
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        4.000000
# max      126.000000
# Name: likesCount, dtype: float64

# %%
commes
# Out:
# count    522.000000
# mean       4.065134
# std        9.436095
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        4.000000
# max       93.000000
# Name: commentsCount, dtype: float64

# %%
from textblob import TextBlob

# %%
# Function to calculate sentiment polarity
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity  # Polarity ranges from -1 (negative) to 1 (positive)

# Apply sentiment analysis
df['sentiment'] = df['text'].apply(get_sentiment)

# View sentiment distribution
df[['text', 'sentiment']].head()
# Out:
#                                                 text  sentiment
# 0  Neat comparison I have not heard it before.\n ...   0.000000
# 1  An excellent way to visualise the invisible! T...   0.600000
# 2  Does the CO2/ghg in the troposphere affect the...   0.000000
# 3  excellent post! I defo feel the difference - o...   0.053571
# 4  Yes, and carbon dioxide does not harm the Eart...  -0.375000

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['text'].dtypes
# Out:
# dtype('O')

# %%
df['text'].head()
# Out:
# 0    Neat comparison I have not heard it before.\n ...
# 1    An excellent way to visualise the invisible! T...
# 2    Does the CO2/ghg in the troposphere affect the...
# 3    excellent post! I defo feel the difference - o...
# 4    Yes, and carbon dioxide does not harm the Eart...
# Name: text, dtype: object

# %%
df['text'] = df['text'].astype(str)

# %%
df[['text', 'sentiment']].hist()
# Out:
# array([[<Axes: title={'center': 'sentiment'}>]], dtype=object)

# %%
plt.figure(figsize=(8,6))
plt.hist(df[ 'sentiment'], bins=10, color='skyblue', edgecolor='black')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from wordcloud import WordCloud

text_data = " ".join(df['text'].dropna())

wordcloud = WordCloud(width=800, height=400).generate(text_data)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
print(df["sentiment"].value_counts())
# Out:
# sentiment
#  0.000000    225
#  0.500000     14
#  0.200000     13
#  0.100000      9
#  0.250000      9
#             ...
#  0.078125      1
#  0.150000      1
#  0.070000      1
#  0.231481      1
# -0.200000      1
# Name: count, Length: 186, dtype: int64

# %%
x=df["text"]
y=df["sentiment"]

# %%
from sklearn.model_selection import train_test_split

# %%
print(f"Original x shape:{len(x)}")
print(f"Original y shape:{len(y)}")
# Out:
# Original x shape:522
# Original y shape:522

# %%
correlation = df[['sentiment', 'likesCount', 'commentsCount']].corr()
print(correlation)
# Out:
#                sentiment  likesCount  commentsCount
# sentiment       1.000000    0.038600      -0.034148
# likesCount      0.038600    1.000000       0.416832
# commentsCount  -0.034148    0.416832       1.000000

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Sentiment and Engagement Metrics')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Preprocess the text data
vectorizer = CountVectorizer(stop_words='english')
text_matrix = vectorizer.fit_transform(df['text'])  # Use the original 'text' column

# Apply LDA
lda = LatentDirichletAllocation(n_components=5, random_state=0)  # You can adjust n_components
lda.fit(text_matrix)

# Display the topics
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

display_topics(lda, vectorizer.get_feature_names_out(), 5)
# Out:
# Topic 0:
# global temperature change climate warming
# Topic 1:
# co2 climate heat weather just
# Topic 2:
# carbon earth years sea dioxide
# Topic 3:
# warming people climate global world
# Topic 4:
# climate change planet nasa earth

# %%
topic_distribution = lda.transform(text_matrix)

# Add the dominant topic for each comment to the DataFrame
df['Dominant Topic'] = topic_distribution.argmax(axis=1)

# Plot the distribution of topics
plt.figure(figsize=(10, 6))
sns.countplot(x='Dominant Topic', data=df ,color='red')
plt.title('Distribution of Dominant Topics')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.show()
